# %%
import torch
from transformers import XLMRobertaTokenizer

#Data "Source lang" : "target lang"
from datasets import load_dataset

ted = load_dataset(ted_multi, split='train')
ted
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:5                                                                                    │
# │                                                                                                  │
# │   2 from transformers import XLMRobertaTokenizer                                                 │
# │   3                                                                                              │
# │   4 #Data "Source lang" : "target lang"                                                          │
# │ ❱ 5 from datasets import load_dataset                                                            │
# │   6                                                                                              │
# │   7 ted = load_dataset(ted_multi, split='train')                                                 │
# │   8 ted                                                                                          │
# │                                                                                                  │
# │ C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\site-packages\datasets\__init__.py:2 │
# │ 2 in <module>                                                                                    │
# │                                                                                                  │
# │   19                                                                                             │
# │   20 __version__ = "2.14.4"                                                                      │
# │   21                                                                                             │
# │ ❱ 22 from .arrow_dataset import Dataset                                                          │
# │   23 from .arrow_reader import ReadInstruction                                                   │
# │   24 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder,    │
# │   25 from .combine import concatenate_datasets, interleave_datasets                              │
# │                                                                                                  │
# │ C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\site-packages\datasets\arrow_dataset │
# │ .py:61 in <module>                                                                               │
# │                                                                                                  │
# │     58 import pandas as pd                                                                       │
# │     59 import pyarrow as pa                                                                      │
# │     60 import pyarrow.compute as pc                                                              │
# │ ❱   61 from huggingface_hub import DatasetCard, DatasetCardData, HfApi, HfFolder                 │
# │     62 from multiprocess import Pool                                                             │
# │     63 from requests import HTTPError                                                            │
# │     64                                                                                           │
# │                                                                                                  │
# │ C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\__init │
# │ __.py:278 in __getattr__                                                                         │
# │                                                                                                  │
# │   275 │   ```                                                                                    │
# │   276 │                                                                                          │
# │   277 │   The idea is to replace a package's `__getattr__`, `__dir__`, and                       │
# │ ❱ 278 │   `__all__`, such that all imports work exactly the way they would                       │
# │   279 │   with normal imports, except that the import occurs upon first use.                     │
# │   280 │                                                                                          │
# │   281 │   The typical way to call this function, replacing the above imports, is:                │
# │                                                                                                  │
# │ C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126 in         │
# │ import_module                                                                                    │
# │                                                                                                  │
# │   123 │   │   │   if character != '.':                                                           │
# │   124 │   │   │   │   break                                                                      │
# │   125 │   │   │   level += 1                                                                     │
# │ ❱ 126 │   return _bootstrap._gcd_import(name[level:], package, level)                            │
# │   127                                                                                            │
# │   128                                                                                            │
# │   129 _RELOADING = {}                                                                            │
# │                                                                                                  │
# │ C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\repoca │
# │ rd.py:20 in <module>                                                                             │
# │                                                                                                  │
# │    17 │   eval_results_to_model_index,                                                           │
# │    18 │   model_index_to_eval_results,                                                           │
# │    19 )                                                                                          │
# │ ❱  20 from huggingface_hub.utils import get_session, is_jinja_available, yaml_dump               │
# │    21                                                                                            │
# │    22 from .constants import REPOCARD_NAME                                                       │
# │    23 from .utils import EntryNotFoundError, SoftTemporaryDirectory, validate_hf_hub_args        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name 'get_session' from 'huggingface_hub.utils'
# (C:\Users\Franek\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\utils\__init__.py)
